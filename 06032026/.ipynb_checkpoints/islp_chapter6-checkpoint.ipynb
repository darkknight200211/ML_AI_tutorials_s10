# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
from statsmodels.api import OLS
import sklearn.model_selection as skm
import sklearn.linear_model as skl
from sklearn.preprocessing import StandardScaler
from ISLP import load_data
from ISLP.models import ModelSpec as MS
from functools import partial

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn. cross_decomposition import PLSRegression
from ISLP.models import \
(Stepwise ,
sklearn_selected ,
sklearn_selection_path )
from l0bnb import fit_path

# %%
Hitters = load_data('Hitters')
np.isnan(Hitters['Salary']).sum()
# Out:
# np.int64(59)

# %%
Hitters = Hitters.dropna();
Hitters.shape
# Out:
# (263, 20)

# %%
def nCp(sigma2 , estimator , X, Y):
    "Negative Cp statistic"
    n, p = X.shape
    Yhat = estimator.predict(X)
    RSS = np.sum((Y - Yhat)**2)
    return -(RSS + 2 * p * sigma2) / n

# %%
design = MS(Hitters.columns.drop('Salary')).fit(Hitters)
Y = np.array(Hitters['Salary'])
X = design.transform(Hitters)
sigma2 = OLS(Y,X).fit().scale

# %%
neg_Cp = partial(nCp , sigma2)

# %%
strategy = Stepwise.first_peak(design ,
direction='forward ',
max_terms=len(design.terms))

# %%
hitters_MSE = sklearn_selected(OLS ,
strategy)
hitters_MSE.fit(Hitters , Y)
hitters_MSE.selected_state_
# Out:
# ('Assists',
#  'AtBat',
#  'CAtBat',
#  'CHits',
#  'CHmRun',
#  'CRBI',
#  'CRuns',
#  'CWalks',
#  'Division',
#  'Errors',
#  'Hits',
#  'HmRun',
#  'League',
#  'NewLeague',
#  'PutOuts',
#  'RBI',
#  'Runs',
#  'Walks',
#  'Years')

# %%
hitters_Cp = sklearn_selected(OLS ,
strategy ,
scoring=neg_Cp)
hitters_Cp.fit(Hitters , Y)
hitters_Cp. selected_state_
# Out:
# ('Assists',
#  'AtBat',
#  'CAtBat',
#  'CRBI',
#  'CRuns',
#  'CWalks',
#  'Division',
#  'Hits',
#  'PutOuts',
#  'Walks')

# %%
strategy = Stepwise.fixed_steps(design ,
len(design.terms),
direction='forward')
full_path = sklearn_selection_path(OLS , strategy)

# %%
full_path.fit(Hitters , Y)
Yhat_in = full_path.predict(Hitters)
Yhat_in.shape
# Out:
# (263, 20)

# %%
mse_fig , ax = subplots(figsize =(8 ,8))
insample_mse = (( Yhat_in - Y[:,None ]) **2).mean (0)
n_steps = insample_mse.shape [0]
ax.plot(np.arange(n_steps),
insample_mse ,
'k', # color black
label='In -sample ')
ax.set_ylabel('MSE',fontsize =20)
ax.set_xlabel('# steps of forward stepwise', fontsize =20)
ax.set_xticks(np.arange(n_steps)[::2])
ax.legend ()
ax.set_ylim ([50000 ,250000]);

# %%
K = 5
kfold = skm.KFold(K,
random_state =0,
shuffle=True)
Yhat_cv = skm.cross_val_predict (full_path ,
Hitters ,
Y,
cv=kfold)
Yhat_cv.shape
# Out:
# (263, 20)

# %%
cv_mse = []
for train_idx , test_idx in kfold.split(Y):
    errors = (Yhat_cv[test_idx] - Y[test_idx ,None])**2
    cv_mse.append(errors.mean (0)) # column means
cv_mse = np.array(cv_mse).T
cv_mse.shape
# Out:
# (20, 5)

# %%
ax.errorbar(np.arange(n_steps),cv_mse.mean (1),cv_mse.std (1) / np.sqrt(K),label='Cross -validated ',c='r') # color red
ax.set_ylim ([50000 ,250000])
ax.legend ()
mse_fig

# %%
validation = skm.ShuffleSplit(n_splits =1,
test_size =0.2,
random_state =0)
for train_idx , test_idx in validation.split(Y):
    full_path.fit(Hitters.iloc[train_idx],
    Y[train_idx ])
    Yhat_val = full_path.predict(Hitters.iloc[test_idx ])
    errors = (Yhat_val - Y[test_idx ,None ])**2
    validation_mse = errors.mean (0)

# %%
ax.plot(np.arange(n_steps),
validation_mse ,
'b--', # color blue , broken line
label='Validation ')
ax.set_xticks(np.arange(n_steps)[::2])
ax.set_ylim ([50000 ,250000])
ax.legend ()
mse_fig

# %%
D = design.fit_transform(Hitters)
D = D.drop('intercept', axis =1)
X = np.asarray(D)

# %%
path = fit_path(X,Y,max_nonzeros=X.shape[1])
# Out:
# Preprocessing Data.
# BnB Started.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 path = fit_path(X,
#       2 Y,
#       3 max_nonzeros=X.shape[1])
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/regpath.py:110, in fit_path(x, y, lambda_2, max_nonzeros, intercept, normalize, m_multiplier, lambda_0_grid, lambda_0_grid_warm_start, gap_tol, time_limit, solver)
#     108 if solver == 'l0bnb':
#     109     tree = BNBTree(x_centered, y_centered)
# --> 110     tree_sol = tree.solve(
#     111         current_lambda_0,
#     112         lambda_2,
#     113         m,
#     114         warm_start=warm_start,
#     115         gap_tol=gap_tol,
#     116         time_limit=time_limit)
#     117     uppersol = tree_sol.beta
#     118 elif solver == 'gurobi':
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/tree.py:138, in BNBTree.solve(self, l0, l2, m, gap_tol, warm_start, mu, branching, l1solver, number_of_dfs_levels, verbose, time_limit, cd_max_itr, kkt_max_itr)
#     135     rel_gap_tol = 1
#     136 # calculate primal and dual values
#     137 curr_primal, curr_dual = self. \
# --> 138     _solve_node(curr_node, l0, l2, m, l1solver, lower_bound,
#     139                 dual_bound, upper_bound, rel_gap_tol, cd_max_itr,
#     140                 kkt_max_itr)
#     142 curr_upper_bound = curr_node.upper_solve(l0, l2, m)
#     143 if curr_upper_bound < upper_bound:
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/tree.py:215, in BNBTree._solve_node(self, curr_node, l0, l2, m, l1solver, lower_, dual_, upper_bound, gap, cd_max_itr, kkt_max_itr)
#     211 def _solve_node(self, curr_node, l0, l2, m, l1solver, lower_, dual_,
#     212                 upper_bound, gap, cd_max_itr, kkt_max_itr):
#     213     self.number_of_nodes += 1
#     214     curr_primal, curr_dual = curr_node. \
# --> 215         lower_solve(l0, l2, m, l1solver, self.rel_tol, self.int_tol,
#     216                     tree_upper_bound=upper_bound, mio_gap=gap,
#     217                     cd_max_itr=cd_max_itr, kkt_max_itr=kkt_max_itr)
#     218     lower_[curr_node.level] = \
#     219         min(curr_primal, lower_.get(curr_node.level, sys.maxsize))
#     220     dual_[curr_node.level] = \
#     221         min(curr_dual, dual_.get(curr_node.level, sys.maxsize))
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/node/core.py:86, in Node.lower_solve(self, l0, l2, m, solver, rel_tol, int_tol, tree_upper_bound, mio_gap, cd_max_itr, kkt_max_itr)
#      82 def lower_solve(self, l0, l2, m, solver, rel_tol, int_tol=1e-6,
#      83                 tree_upper_bound=None, mio_gap=None, cd_max_itr=100,
#      84                 kkt_max_itr=100):
#      85     if solver == 'l1cd':
# ---> 86         sol = cd_solve(x=self.x, y=self.y, l0=l0, l2=l2, m=m, zlb=self.zlb,
#      87                        zub=self.zub, xi_norm=self.xi_norm, rel_tol=rel_tol,
#      88                        warm_start=self.warm_start, r=self.r,
#      89                        tree_upper_bound=tree_upper_bound, mio_gap=mio_gap,
#      90                        gs_xtr=self.gs_xtr, gs_xb=self.gs_xb,
#      91                        cd_max_itr=cd_max_itr, kkt_max_itr=kkt_max_itr)
#      92         self.primal_value = sol.primal_value
#      93         self.dual_value = sol.dual_value
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/relaxation/core.py:137, in solve(x, y, l0, l2, m, zlb, zub, gs_xtr, gs_xb, xi_norm, warm_start, r, rel_tol, tree_upper_bound, mio_gap, check_if_integral, cd_max_itr, kkt_max_itr)
#     132 _sol_str = \
#     133     'primal_value dual_value support primal_beta sol_time z r gs_xtr gs_xb'
#     134 Solution = namedtuple('Solution', _sol_str)
#     136 beta, r, support, zub, zlb, xi_norm = \
# --> 137     _initialize(x, y, l0, l2, m, zlb, zub, xi_norm, warm_start, r)
#     138 cost, _ = get_primal_cost(beta, r, l0, l2, m, zlb, zub)
#     139 dual_cost = None
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/relaxation/core.py:64, in _initialize(x, y, l0, l2, m, fixed_lb, fixed_ub, xi_norm, warm_start, r)
#      62     beta = np.zeros(p)
#      63     r = y - np.matmul(x, beta)
# ---> 64     support, r = _find_active_set(x, y, beta, l0, l2, m, zlb, zub, xi_norm,
#      65                                   {0}, r)
#      66 return beta, r, support, zub, zlb, xi_norm
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/l0bnb/relaxation/core.py:26, in _find_active_set(x, y, beta, l0, l2, m, zlb, zub, xi_norm, support, r)
#      25 def _find_active_set(x, y, beta, l0, l2, m, zlb, zub, xi_norm, support, r):
# ---> 26     _ratio, threshold = get_ratio_threshold(l0, l2, m)
#      27     correlations = np.matmul(y, x) / xi_norm
#      28     partition = np.argpartition(-correlations, int(0.2 * len(beta)))
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/dispatcher.py:443, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     441             e.patch_message('\n'.join((str(e).rstrip(), help_msg)))
#     442     # ignore the FULL_TRACEBACKS config, this needs reporting!
# --> 443     raise e
#     444 finally:
#     445     self._types_active_call.clear()
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler.py:481, in CompilerBase._compile_core(self)
#     479 except Exception as e:
#     480     if not isinstance(e, errors.NumbaError):
# --> 481         raise e
#     482     self.state.status.fail_reason = e
#     483     if is_final_pipeline:
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler_machinery.py:363, in PassManager.run(self, state)
#     361 except Exception as e:
#     362     if not isinstance(e, errors.NumbaError):
# --> 363         raise e
#     364     msg = "Failed in %s mode pipeline (step: %s)" % \
#     365         (self.pipeline_name, pass_desc)
#     366     patched_exception = self._patch_error(msg, e)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typed_passes.py:114, in BaseTypeInference.run_pass(self, state)
#     108 """
#     109 Type inference and legalization
#     110 """
#     111 with fallback_context(state, 'Function "%s" failed type inference'
#     112                       % (state.func_id.func_name,)):
#     113     # Type inference
# --> 114     typemap, return_type, calltypes, errs = type_inference_stage(
#     115         state.typingctx,
#     116         state.targetctx,
#     117         state.func_ir,
#     118         state.args,
#     119         state.return_type,
#     120         state.locals,
#     121         raise_errors=self._raise_errors)
#     122     state.typemap = typemap
#     123     # save errors in case of partial typing
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typed_passes.py:95, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      93     infer.build_constraint()
#      94     # return errors in case of partial typing
# ---> 95     errs = infer.propagate(raise_errors=raise_errors)
#      96     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      98 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typeinfer.py:1075, in TypeInferer.propagate(self, raise_errors)
#    1072 oldtoken = newtoken
#    1073 # Errors can appear when the type set is incomplete; only
#    1074 # raise them when there is no progress anymore.
# -> 1075 errors = self.constraints.propagate(self)
#    1076 newtoken = self.get_state_token()
#    1077 self.debug.propagate_finished()
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typeinfer.py:716, in GetAttrConstraint.__call__(self, typeinfer)
#     714 valtys = typevars[self.value.name].get()
#     715 for ty in valtys:
# --> 716     attrty = typeinfer.context.resolve_getattr(ty, self.attr)
#     717     if attrty is None:
#     718         raise UntypedAttributeError(ty, self.attr,
#     719                                     loc=self.inst.loc)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typing/context.py:370, in BaseContext.resolve_getattr(self, typ, attr)
#     367     return out
#     369 if isinstance(typ, types.Module):
# --> 370     attrty = self.resolve_module_constants(typ, attr)
#     371     if attrty is not None:
#     372         return attrty
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numba/core/typing/context.py:435, in BaseContext.resolve_module_constants(self, typ, attr)
#     430 """
#     431 Resolve module-level global constants.
#     432 Return None or the attribute type
#     433 """
#     434 assert isinstance(typ, types.Module)
# --> 435 attrval = getattr(typ.pymod, attr)
#     436 try:
#     437     return self.resolve_value_type(attrval)
#
# File ~/college_work/sem10/ML_AI/ML_AI_environment/ML_AI_env/lib64/python3.14/site-packages/numpy/__init__.py:778, in __getattr__(attr)
#     775     raise AttributeError(__former_attrs__[attr], name=None)
#     777 if attr in __expired_attributes__:
# --> 778     raise AttributeError(
#     779         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     780         f"{__expired_attributes__[attr]}",
#     781         name=None
#     782     )
#     784 if attr == "chararray":
#     785     warnings.warn(
#     786         "`np.chararray` is deprecated and will be removed from "
#     787         "the main namespace in the future. Use an array with a string "
#     788         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.Inf` was removed in the NumPy 2.0 release. Use `np.inf` instead.
