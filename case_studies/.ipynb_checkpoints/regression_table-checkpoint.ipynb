# %% [markdown]
# # Regression Table #

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split

# %%
#### importing a dataset from kaggle
path_t0_data    =    "/home/jwalitnpanchal/college_work/sem10/ML_AI/case_studies/gold_price_forecasting_dataset.csv"
data1           =    pd.read_csv(path_t0_data)
#print(data1.info())
print(data1.head())
# Out:
#          date    adj close        close         high          low  \
# 0  2021-06-11  1877.400024  1877.400024  1902.300049  1875.199951
# 1  2021-06-14  1864.000000  1864.000000  1866.599976  1846.500000
# 2  2021-06-15  1854.500000  1854.500000  1867.199951  1854.400024
# 3  2021-06-16  1859.500000  1859.500000  1860.099976  1809.199951
# 4  2021-06-17  1773.800049  1773.800049  1823.300049  1769.599976
#
#           open  volume         ma_7        ma_30        ma_90  daily_return  \
# 0  1900.900024     349  1887.828561  1860.180005  1790.618891     -0.008869
# 1  1866.199951      41  1886.799997  1863.403337  1790.972225     -0.007138
# 2  1866.400024      78  1881.757132  1865.506669  1791.701114     -0.005097
# 3  1859.400024     117  1876.428554  1868.296667  1792.241113      0.002696
# 4  1811.800049    1135  1859.514282  1867.953337  1791.595558     -0.046088
#
#    volatility_7  volatility_30        rsi       macd  macd_signal  \
# 0      0.009353       0.007538  54.722931  19.724030    24.933953
# 1      0.006411       0.007711  49.391919  16.433420    23.233846
# 2      0.004572       0.007474  45.972581  12.910196    21.169116
# 3      0.004348       0.007240  48.012515  10.401571    19.015607
# 4      0.016895       0.011288  28.293542   1.481124    15.508710
#
#       bb_upper     bb_lower
# 0  1918.242879  1853.797124
# 1  1913.119794  1861.530206
# 2  1914.969370  1858.380630
# 3  1915.862799  1856.657196
# 4  1938.202457  1823.567538

# %%
###### extracting some predictors and one response
# predictors
opening_price    =    np.asarray(data1["open"].values).reshape(-1,1)
trade_volume     =    np.asarray(data1["volume"].values).reshape(-1,1)
ma_7_arr         =    np.asarray(data1["ma_7"].values).reshape(-1,1)
volatility_7_arr =    np.asarray(data1["volatility_7"].values).reshape(-1,1)
# response
daily_ret_arr    =    np.asarray(data1["daily_return"].values).reshape(-1,1)
######### stack the predictors into one matrix
predictor_stack =    np.column_stack((opening_price,trade_volume, ma_7_arr, volatility_7_arr))
print(predictor_stack)
predictor_stack       =    sm.add_constant(predictor_stack)
### split the data into parts
predictors_train, predictors_test, daily_ret_train, daily_ret_test    =    train_test_split(predictor_stack, daily_ret_arr, random_state=45, test_size=0.25)
######## train the model on the train dat:
print(daily_ret_train.shape, predictors_train.shape)
model_gold_pricing     =    sm.OLS(daily_ret_train, predictors_train)
fit_model_gold_pricing =    model_gold_pricing.fit()
print(fit_model_gold_pricing.summary())
# Out:
# [[1.90090002e+03 3.49000000e+02 1.88782856e+03 9.35330708e-03]
#  [1.86619995e+03 4.10000000e+01 1.88680000e+03 6.41073817e-03]
#  [1.86640002e+03 7.80000000e+01 1.88175713e+03 4.57208047e-03]
#  ...
#  [5.30160010e+03 1.12054000e+05 4.99108573e+03 1.48918955e-02]
#  [5.41570020e+03 2.37090000e+04 5.07091427e+03 1.42146590e-02]
#  [5.37639990e+03 2.37090000e+04 5.05407143e+03 5.11055932e-02]]
# (875, 1) (875, 5)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     7.907
# Date:                Wed, 04 Feb 2026   Prob (F-statistic):           2.92e-06
# Time:                        08:47:17   Log-Likelihood:                 2731.2
# No. Observations:                 875   AIC:                            -5452.
# Df Residuals:                     870   BIC:                            -5428.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.179      0.858      -0.002       0.003
# x1          5.469e-06   1.05e-05      0.521      0.603   -1.51e-05    2.61e-05
# x2         -2.165e-10   1.62e-08     -0.013      0.989   -3.21e-08    3.17e-08
# x3         -3.428e-06   1.07e-05     -0.320      0.749   -2.45e-05    1.76e-05
# x4            -0.4669      0.091     -5.156      0.000      -0.645      -0.289
# ==============================================================================
# Omnibus:                      241.631   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3794.028
# Skew:                          -0.811   Prob(JB):                         0.00
# Kurtosis:                      13.071   Cond. No.                     5.69e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.69e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
response_col    =    "daily_return"
predictors      =    data1.loc[:, data1.columns != response_col]
predictors      =    predictors.drop(columns="date")
predictors      =    sm.add_constant(predictors)
#print(predictors)
response        =    data1.loc[:, response_col]
### split the data into parts
predictors_train1, predictors_test1, daily_ret_train1, daily_ret_test1    =    train_test_split(predictors, response, random_state=45, test_size=0.25)
# Out:
#         adj close        close         high          low         open  volume  \
# 0     1877.400024  1877.400024  1902.300049  1875.199951  1900.900024     349
# 1     1864.000000  1864.000000  1866.599976  1846.500000  1866.199951      41
# 2     1854.500000  1854.500000  1867.199951  1854.400024  1866.400024      78
# 3     1859.500000  1859.500000  1860.099976  1809.199951  1859.400024     117
# 4     1773.800049  1773.800049  1823.300049  1769.599976  1811.800049    1135
# ...           ...          ...          ...          ...          ...     ...
# 1162  5079.700195  5079.700195  5095.600098  5052.200195  5081.500000     180
# 1163  5079.899902  5079.899902  5079.899902  5079.899902  5079.899902      34
# 1164  5301.600098  5301.600098  5301.600098  5301.600098  5301.600098  112054
# 1165  5318.399902  5318.399902  5586.200195  5097.500000  5415.700195   23709
# 1166  4713.899902  4713.899902  5440.500000  4700.000000  5376.399902   23709
#
#              ma_7        ma_30        ma_90  volatility_7  volatility_30  \
# 0     1887.828561  1860.180005  1790.618891      0.009353       0.007538
# 1     1886.799997  1863.403337  1790.972225      0.006411       0.007711
# 2     1881.757132  1865.506669  1791.701114      0.004572       0.007474
# 3     1876.428554  1868.296667  1792.241113      0.004348       0.007240
# 4     1859.514282  1867.953337  1791.595558      0.016895       0.011288
# ...           ...          ...          ...           ...            ...
# 1162  4822.971401  4513.550000  4189.464434      0.014470       0.014899
# 1163  4889.199986  4540.029997  4204.998877      0.014091       0.014677
# 1164  4991.085728  4573.413330  4223.419990      0.014892       0.016210
# 1165  5070.914272  4607.136654  4241.718877      0.014215       0.016193
# 1166  5054.071429  4620.783317  4252.532210      0.051106       0.027369
#
#             rsi        macd  macd_signal     bb_upper     bb_lower
# 0     54.722931   19.724030    24.933953  1918.242879  1853.797124
# 1     49.391919   16.433420    23.233846  1913.119794  1861.530206
# 2     45.972581   12.910196    21.169116  1914.969370  1858.380630
# 3     48.012515   10.401571    19.015607  1915.862799  1856.657196
# 4     28.293542    1.481124    15.508710  1938.202457  1823.567538
# ...         ...         ...          ...          ...          ...
# 1162  82.883455  169.000739   122.250355  5019.523790  4155.806191
# 1163  82.887953  182.167754   134.233835  5096.080527  4134.329434
# 1164  86.978544  208.093290   149.005726  5210.931481  4117.128480
# 1165  87.227702  227.374043   164.679389  5310.168254  4112.721688
# 1166  50.088570  191.666666   170.076845  5302.863243  4158.856679
#
# [1167 rows x 16 columns]
