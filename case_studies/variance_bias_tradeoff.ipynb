# %% [markdown]
# ## Variance and Bias
# <p align="center">
# <img src="variance_bias_tradeoff.png" alt="Lorenz attractor" width="400">
# </p>
# \begin{equation}
#     E(y_{0}-\hat{f}(x_{0}))^{2} = \text{Var}(\hat{f}(x_{0})) + [\text{Bias}(\hat{f}(x_{0}))]^{2}+ \text{Var}(\epsilon)
# \end{equation}
