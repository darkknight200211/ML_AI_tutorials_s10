# %%
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
import ML_user_def_functions as ML_fns
import pandas as pd

# %%
path_to_data = "/home/jwalitnpanchal/college_work/sem10/ML_AI/Gross domestic product (GDP) and main components per capita (nama_10_pc).csv"
data_frame = pd.read_csv(path_to_data)
print(data_frame, "\n")
#print(data_frame.info())
# Out:
#      frq                unit na_itm   go   1995   1996   1997   1998   1999  \
# 0      A         CLV10_UR_HA    1GQ   AL   1370   1480   1310   1430   1620
# 1      A         CLV10_UR_HA    1GQ   AT  27450  28020  28590  29560  30610
# 2      A         CLV10_UR_HA    1GQ  NaN  26270  26560  27500  27980  28910
# 3      A         CLV10_UR_HA    1GQ    G   3240   3430   2960   3090   2850
# 4      A         CLV10_UR_HA    1GQ   CH  48350  48400  49270  50470  51050
# ...   ..                 ...    ...  ...    ...    ...    ...    ...    ...
# 4486   A  C_U27_2020_HA_MS_C     41    S  126.6  127.6  127.1  126.2  128.8
# 4487   A  C_U27_2020_HA_MS_C     41   SI   79.6     79   80.2     80   82.1
# 4488   A  C_U27_2020_HA_MS_C     41   SK   40.9   47.1   49.1   50.4   47.7
# 4489   A  C_U27_2020_HA_MS_C     41   TR
# 4490   A  C_U27_2020_HA_MS_C     41   UK  126.4  129.9  133.2  132.3    132
#
#        2000  ...     2015     2016   2017   2018   2019   2020   2021   2022  \
# 0      1750  ...   3480.0   3620.0   3750   3890   3990   3880   4270   4530
# 1     31510  ...  35930.0  36230.0  36820  37550  38040  35480  37080  38620
# 2     29910  ...  34090.0  34320.0  34700  35190  35850  33990  35960  37090
# 3      2990  ...   5850.0   6110.0   6360   6600   6950   6800   7380   7730
# 4     52630  ...  60400.0  60900.0  61200  62780  63030  61140  64440  66160
# ...     ...  ...      ...      ...    ...    ...    ...    ...    ...    ...
# 4486  129.9  ...    124.0    121.3  118.3  116.6  114.4  117.9  117.6  110.7
# 4487   80.2  ...     78.2     79.0   79.4   80.4     83   83.4   87.5   89.5
# 4488   47.2  ...     72.0     68.4   67.7   67.4   68.7   75.2   75.1   76.6
# 4489         ...     64.9     62.8   61.9     57   54.4     56   54.7   59.1
# 4490  134.2  ...    126.0    124.0  121.9  119.7  117.5
#
#        2023   2024
# 0
# 1     37990  37550
# 2     37400  37580
# 3      7880   8160
# 4     65710  65880
# ...     ...    ...
# 4486  108.9  108.3
# 4487   87.7   88.7
# 4488     77   78.2
# 4489     63   65.8
# 4490
#
# [4491 rows x 34 columns]
